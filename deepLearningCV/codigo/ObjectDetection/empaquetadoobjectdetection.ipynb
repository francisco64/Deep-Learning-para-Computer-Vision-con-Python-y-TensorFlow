# %%
# !git clone https://github.com/tensorflow/models.git

# %%
# !protoc /kaggle/working/models/research/object_detection/protos/*.proto --python_out=/models/research

# %%
# !cp /kaggle/working/models/research/object_detection/packages/tf2/setup.py /kaggle/working/models/research

# %%
# !python /kaggle/working/models/research/setup.py sdist

# %%
 # !cp /kaggle/working/models/research/dist/object_detection-0.1.tar.gz /kaggle/working

# %%
#Ya prodríamos correr el comando
#!pip install /kaggle/working/models/research/dist/object_detection-0.1.tar.gz
